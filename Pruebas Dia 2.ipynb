# %%
x=int(input("Por favor digite un valor entero para x: "))

operacion1=1/x
operacion2= x+operacion1
operacion3= x+1/operacion2
operacion4= x+1/operacion3
y= 1/operacion4

print("el resultado de la expresion es: ",y)
# Out:
# Por favor digite un valor entero para x: 58
# el resultado de la expresion es:  0.017236257093817035
